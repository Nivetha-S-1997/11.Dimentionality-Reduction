# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')
dataset.drop('User ID',axis=1,inplace=True)
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0         True
# 1     35            20000          0         True
# 2     26            43000          0        False
# 3     27            57000          0        False
# 4     19            76000          0         True
# ..   ...              ...        ...          ...
# 395   46            41000          1        False
# 396   51            23000          1         True
# 397   50            20000          1        False
# 398   36            33000          0         True
# 399   49            36000          1        False
#
# [400 rows x 4 columns]

# %%
independent=dataset.drop('Purchased',axis=1)
dependent=dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.25,random_state=0)
#X_train

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
#X_train

# %%
def KPrincipleComponentAnalysis(X_train,X_test,n):
    from sklearn.decomposition import KernelPCA
    kpca=KernelPCA(n_components=n,kernel='rbf')
    X_train=kpca.fit_transform(X_train)
    X_test=kpca.transform(X_test)
    return X_train,X_test

# %%
def pred_confusion(classifier,X_test,Y_test):
    Y_pred=classifier.predict(X_test)
    
    cm=confusion_matrix(Y_test,Y_pred)
    accuracy=accuracy_score(Y_test,Y_pred)
    report=classification_report(Y_test,Y_pred)
    return cm,accuracy,report

# %%
def logistic(X_train,Y_train):
    classifier=LogisticRegression(random_state=0)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def svml(X_train,Y_train):
    classifier=SVC(kernel='linear',random_state=0)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def svmnl(X_train,Y_train):
    classifier=SVC(kernel='rbf',random_state=0)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def decisiontree(X_train,Y_train):
    classifier=DecisionTreeClassifier(criterion='entropy',random_state=0)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def randomforest(X_train,Y_train):
    classifier=RandomForestClassifier(n_estimators=10,criterion='entropy',random_state=0)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def naive_bayes(X_train,Y_train):
    classifier=GaussianNB()
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

def knn(X_train,Y_train):
    classifier=KNeighborsClassifier(n_neighbors=15,metric='minkowski',p=2)
    classifier.fit(X_train,Y_train)
    
    cm,accuracy,report=pred_confusion(classifier,X_test,Y_test)
    return classifier,cm,accuracy,report

# %%
def kpca_table(acclog,accsvml,accsvmnl,accdt,accrf,accnb,accknn):
    dataframe=pd.DataFrame(index=['KPCA'],columns=['Logistic','SVML','SVMNL','DecisionTree','RandomForest','NaiveBayes','KNN'])

    for number,index in enumerate(dataframe.index):
        dataframe['Logistic'][index]=acclog[number]
        dataframe['SVML'][index]=accsvml[number]
        dataframe['SVMNL'][index]=accsvmnl[number]
        dataframe['DecisionTree'][index]=accdt[number]
        dataframe['RandomForest'][index]=accrf[number]
        dataframe['NaiveBayes'][index]=accnb[number]
        dataframe['KNN'][index]=accknn[number]
    return dataframe

# %%
acclog=[]
accsvml=[]
accsvmnl=[]
accdt=[]
accrf=[]
accnb=[]
accknn=[]

# %%
X_train,X_test=KPrincipleComponentAnalysis(X_train,X_test,2)

# %%
classifier,cm,accuracy,report=logistic(X_train,Y_train)
acclog.append(accuracy)
    
classifier,cm,accuracy,report=svml(X_train,Y_train)
accsvml.append(accuracy)
    
classifier,cm,accuracy,report=svmnl(X_train,Y_train)
accsvmnl.append(accuracy)
    
classifier,cm,accuracy,report=decisiontree(X_train,Y_train)
accdt.append(accuracy)
    
classifier,cm,accuracy,report=randomforest(X_train,Y_train)
accrf.append(accuracy)
    
classifier,cm,accuracy,report=naive_bayes(X_train,Y_train)
accnb.append(accuracy)
    
classifier,cm,accuracy,report=knn(X_train,Y_train)
accknn.append(accuracy)

# %%
result=kpca_table(acclog,accsvml,accsvmnl,accdt,accrf,accnb,accknn)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['Logistic'][index]=acclog[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['SVML'][index]=accsvml[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['SVMNL'][index]=accsvmnl[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['DecisionTree'][index]=accdt[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:9: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['RandomForest'][index]=accrf[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['NaiveBayes'][index]=accnb[number]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6364\3236723455.py:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe['KNN'][index]=accknn[number]

# %%
result
#5
# Out:
#      Logistic  SVML SVMNL DecisionTree RandomForest NaiveBayes   KNN
# KPCA     0.91  0.91  0.93         0.93         0.92       0.93  0.93

# %%
result
#4
# Out:
#      Logistic  SVML SVMNL DecisionTree RandomForest NaiveBayes   KNN
# KPCA     0.91  0.91  0.93         0.93         0.92       0.93  0.93

# %%
result
#3
# Out:
#      Logistic  SVML SVMNL DecisionTree RandomForest NaiveBayes   KNN
# KPCA     0.91  0.91  0.93         0.93         0.92       0.93  0.93

# %%
result
#2
# Out:
#      Logistic  SVML SVMNL DecisionTree RandomForest NaiveBayes   KNN
# KPCA     0.91  0.91  0.93         0.93         0.92       0.93  0.93
